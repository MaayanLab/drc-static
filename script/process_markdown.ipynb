# %%
import pandas as pd
import yaml

# %%
dccs = pd.read_csv('data/DCC.tsv', sep="\t", index_col=0)
dccs = dccs.fillna('')
dccs.head()
# Out:
#                                                                                   label  \
# id
# a1289ebb-0306-59a1-b0fc-e4d03a4790d7                  Illuminating the Druggable Genome
# dd66e8a5-0e05-5a43-a0ca-18cc3698bb36                    The Cellular Senescence Network
# f65babf7-2875-5725-9635-210d654533f1                    Extracellular RNA Communication
# f3f490cf-fd69-579c-8ea3-472c7cf3fb59  Library of Integrated Network-based Cellular S...
# 089d8d63-3364-526f-9706-80d62d0ec88c                                       Metabolomics
#
#                                                                             description  \
# id
# a1289ebb-0306-59a1-b0fc-e4d03a4790d7  To improve our scientific understanding of und...
# dd66e8a5-0e05-5a43-a0ca-18cc3698bb36  The Common Fund’s Cellular Senescence Network ...
# f65babf7-2875-5725-9635-210d654533f1  The Extracellular RNA Communication program is...
# f3f490cf-fd69-579c-8ea3-472c7cf3fb59  The Common Fund’s Library of Integrated Networ...
# 089d8d63-3364-526f-9706-80d62d0ec88c  The goal of the Common Fund’s Metabolomics pro...
#
#                                                                     homepage  \
# id
# a1289ebb-0306-59a1-b0fc-e4d03a4790d7            https://druggablegenome.net/
# dd66e8a5-0e05-5a43-a0ca-18cc3698bb36           https://sennetconsortium.org/
# f65babf7-2875-5725-9635-210d654533f1                      https://exrna.org/
# f3f490cf-fd69-579c-8ea3-472c7cf3fb59               https://lincsproject.org/
# 089d8d63-3364-526f-9706-80d62d0ec88c  https://www.metabolomicsworkbench.org/
#
#                                                                                    icon  \
# id
# a1289ebb-0306-59a1-b0fc-e4d03a4790d7                                       /img/IDG.png
# dd66e8a5-0e05-5a43-a0ca-18cc3698bb36                                    /img/SenNet.png
# f65babf7-2875-5725-9635-210d654533f1                                     /img/exRNA.png
# f3f490cf-fd69-579c-8ea3-472c7cf3fb59  https://cfde-drc.s3.amazonaws.com/assets/img/L...
# 089d8d63-3364-526f-9706-80d62d0ec88c                              /img/Metabolomics.png
#
#                                      annotation   short_label  cfde_partner  \
# id
# a1289ebb-0306-59a1-b0fc-e4d03a4790d7                      IDG          True
# dd66e8a5-0e05-5a43-a0ca-18cc3698bb36                   SenNet          True
# f65babf7-2875-5725-9635-210d654533f1                    ExRNA          True
# f3f490cf-fd69-579c-8ea3-472c7cf3fb59                    LINCS          True
# 089d8d63-3364-526f-9706-80d62d0ec88c             Metabolomics          True
#
#                                                                       cf_site  \
# id
# a1289ebb-0306-59a1-b0fc-e4d03a4790d7           https://commonfund.nih.gov/IDG
# dd66e8a5-0e05-5a43-a0ca-18cc3698bb36    https://commonfund.nih.gov/senescence
# f65babf7-2875-5725-9635-210d654533f1         https://commonfund.nih.gov/ExRNA
# f3f490cf-fd69-579c-8ea3-472c7cf3fb59         https://commonfund.nih.gov/LINCS
# 089d8d63-3364-526f-9706-80d62d0ec88c  https://commonfund.nih.gov/Metabolomics
#
#                                       active
# id
# a1289ebb-0306-59a1-b0fc-e4d03a4790d7    True
# dd66e8a5-0e05-5a43-a0ca-18cc3698bb36    True
# f65babf7-2875-5725-9635-210d654533f1    True
# f3f490cf-fd69-579c-8ea3-472c7cf3fb59    True
# 089d8d63-3364-526f-9706-80d62d0ec88c    True

# %%
for i, row in dccs.iterrows():
	yml = {"layout": "../../layouts/DCC.astro"}
	if row['active']:
		description = ''
		for k,v in row.items():
			if not k == 'description':
				if not v == '':
					if k == 'icon' and v.startswith('/img'):
						v = "https://cfde-drc.s3.amazonaws.com/assets" + v

					yml[k] = v
			else:
				description = v
		with open('out/dccs/%s.md'%row['short_label'], 'w') as o:
			o.write('---\n')
			o.write(yaml.dump(yml))
			o.write('---\n')
			o.write(description)

# %%
publications = pd.read_csv('data/publications.tsv', sep="\t")
publications = publications[[i for i in publications.columns if not i == "id"]]
publications = publications.fillna('')
publications.head()
# Out:
#                                                title  \
# 0  Computational screen to identify potential tar...
# 1  Contribution of Circulating Host and Microbial...
# 2  Lactate-dependent transcriptional regulation c...
# 3  Modular and mechanistic changes across stages ...
# 4  The stability of the myelinating oligodendrocy...
#
#                                              journal  \
# 0                                         Aging cell
# 1  International journal of tryptophan research :...
# 2                              Nature communications
# 3                                         BMC cancer
# 4                                       Cell reports
#
#                                              authors  year               page  \
# 0  Deng EZ, Fleishman RH, Xie Z, Marino GB, Clark...  2023             e13809
# 1  Morgan EW, Dong F, Annalora AJ, Murray IA, Wol...  2023  11786469231182510
# 2  Takata N, Miska JM, Morgan MA, Patel P, Billin...  2023               4129
# 3  Rahiminejad S, Maurya MR, Mukund K, Subramaniam S  2022                436
# 4  Pruvost M, Patzig J, Yattah C, Selcen I, Herna...  2023             112848
#
#   volume issue        pmid        pmcid                           doi  ...  \
# 0     22     6  37082798.0  PMC10265163            10.1111/acel.13809  ...
# 1     16        37441265.0  PMC10334013     10.1177/11786469231182510  ...
# 2     14     1  37452018.0  PMC10349100    10.1038/s41467-023-39672-2  ...
# 3     22     1  35448980.0   PMC9022252    10.1186/s12885-022-09479-3  ...
# 4     42     8  37515770.0  PMC10600948  10.1016/j.celrep.2023.112848  ...
#
#            dccs partnerships carousel carousel_title  carousel_link  \
# 0         LINCS                 False
# 1  Metabolomics                 False
# 2  Metabolomics                 False
# 3  Metabolomics                 False
# 4  Metabolomics                 False
#
#   carousel_description image featured r03  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#                                             keywords
# 0  ["neoantigens", "Gene Expression Profiling", "...
# 1  ["microbiome", "metabolomics", "indole", "Aryl...
# 2  ["Eye", "Gene Expression Regulation", "Mice", ...
# 3  ["Gene Expression Profiling", "Computational B...
# 4  ["Chromatin", "Oligodendroglia", "progenitors"...
#
# [5 rows x 22 columns]

# %%
for i, row in publications.iterrows():
	yml = {"layout": "../../layouts/Publication.astro"}
	for k,v in row.items():
		if not v == '':
			if k == 'dccs':
				v = v.split("; ")
			if k == "pmid":
				v = int(v)
			yml[k] = v
	filename = "PMID: %s"%str(int(yml['pmid'])) if "pmid" in yml else "DOI: %s"%yml['doi'].replace("/", "-")
	with open('out/publications/%s.md'%filename, 'w') as o:
		o.write('---\n')
		o.write(yaml.dump(yml))
		o.write('\n---')

# %%
int(100.0)
# Out:
# 100

# %%
row
# Out:
# title                   Predictive analyses of regulatory sequences wi...
# journal                                      Nature Computational Science
# authors                 Klie A; Laub D; Talwar JV; Stites H; Jores T; ...
# year                                                                 2023
# page                                                              946-956
# volume                                                                  3
# issue                                                                  11
# pmid                                                           38177592.0
# pmcid                                                         PMC10768637
# doi                                            10.1038/s43588-023-00544-w
# landmark                                                            False
# tool_id
# dccs
# partnerships
# carousel                                                            False
# carousel_title
# carousel_link
# carousel_description
# image
# featured                                                            False
# r03
# keywords                   ["Workflow", "Genome", "Genomics", "Software"]
# Name: 84, dtype: object
